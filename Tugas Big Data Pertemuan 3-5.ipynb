# %%
import requests
import os
import zipfile
import re
from tqdm import tqdm

# %%
def download_file(url, local_filename):
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size = 8192):
                f.write(chunk)
    return local_filename

# %%
# url = 'http://data.gdeltproject.org/gdeltv2/masterfilelist.txt'
# local_filename = 'masterfilelist.txt'
# download_file(url, local_filename)

# %%
# with open(local_filename) as f:
#     master_csv = f.readlines()

# %%
# for line in master_csv:
#     print(line)

# %%
# master_link = [line.split(" ")[-1] for line in master_csv]
# master_link = [x.split()[-1] for x in master_csv]
# master_link = [x for x in master_link if "export" in x]
# master_link

# %%
# master_link_dated = [(x, int(re.findall('\d+', x)[-1]))for x in master_link]
# master_link_dated = [(x, int(re.findall(r'\d{4}', x)[0])) for x in master_link if re.findall(r'\d{4}', x)]
# master_link_dated_filtered = [x[0] for x in master_link_dated if x[1] > 2021]
# master_link_dated_filtered

# %%
# # for link in tqdm (master_link_dated_filtered):
# #     download_file(link, f"zip/{link.split('/')[-1]}")

# skip_link = "http://data.gdeltproject.org/gdeltv2/20221110220000.export.CSV.zip"
# problematic_links = []

# for link in tqdm(master_link_dated_filtered):
#     # Skip the specified link
#     if link == skip_link:
#         print(f"Skipping link: {link}")
#         continue
    
#     # Extract file name from the link
#     file_name = f'zip/{link.split("/")[-1]}'
    
#     # Check if file already exists
#     if os.path.exists(file_name):
#         print(f"File {file_name} already exists. Skipping download.")
#         continue
    
#     try:
#         # Attempt to download the file
#         download_file(link, file_name)
#         print(f"Downloaded: {file_name}")
#     except Exception as e:
#         # Add the link to the problematic list
#         print(f"Failed to download {file_name}: {str(e)}. Skipping.")
#         problematic_links.append(link)

# %%
# import zipfile
# from glob import glob

# def extract_zip(zip_path, extract_to_path):
#     try:
#         with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#             zip_ref.extractall(extract_to_path)
#         return True
#     except zipfile.BadZipFile:
#         return False

# # Ambil semua file ZIP dari folder 'zip/'
# zip_files = glob('zip/*.zip')

# # List untuk menyimpan file yang sukses dan gagal
# success_files = []
# failed_files = []

# # Loop melalui setiap file ZIP dengan progress bar dari tqdm
# for file in tqdm(zip_files, desc="Extracting ZIP files", unit="file"):
#     if extract_zip(file, 'csv'):
#         success_files.append(file)
#     else:
#         failed_files.append(file)

# # Setelah selesai, print hasil
# print("\nExtraction complete!")
# print(f"Successfully extracted files: {len(success_files)}")
# for file in success_files:
#     print(f" - {file}")

# print(f"\nFailed to extract files: {len(failed_files)}")
# for file in failed_files:
#     print(f" - {file}")

# %%
# # Check if the file exists in the expected folder
# file_path = 'source_zip/csv/20220101000000.export.CSV'
# if os.path.exists(file_path):
#     print(f"File {file_path} exists.")
# else:
#     print(f"File {file_path} not found.")
    
# # List the files in the directory to ensure it's there
# print("Files in source_zip/csv directory:", os.listdir('source_zip/csv'))

# %%
# import pandas as pd
# import os

# # Folder tempat file CSV yang sudah diekstrak
# csv_folder = 'csv/'

# # File hasil penggabungan akhir
# combined_output_file = 'final_combined_output.csv'

# # Daftar semua file CSV di dalam folder
# csv_files = [f for f in os.listdir(csv_folder) if f.endswith('.CSV') or f.endswith('.csv')]

# # Daftar file yang berhasil dan gagal dibaca
# successful_files = []
# failed_files = []

# # Buat header untuk file keluaran hanya sekali (di file pertama)
# header_written = False

# # Loop melalui semua file CSV
# for file in csv_files:
#     file_path = os.path.join(csv_folder, file)
    
#     try:
#         # Membaca file CSV dengan delimiter tab
#         df = pd.read_csv(file_path, sep='\t', engine='python')
        
#         # Simpan langsung ke file keluaran, tambahkan header hanya untuk file pertama
#         df.to_csv(combined_output_file, mode='a', header=not header_written, index=False)
#         header_written = True
        
#         successful_files.append(file)
#         print(f"Successfully read and added {file}")
#     except Exception as e:
#         # Jika gagal, tambahkan file ke daftar yang gagal
#         failed_files.append(file)
#         print(f"Failed to read {file}: {str(e)}")

# # Print hasil file yang sukses dan gagal
# print(f"\nSuccessfully processed {len(successful_files)} files:")
# for file in successful_files:
#     print(f" - {file}")

# print(f"\nFailed to process {len(failed_files)} files:")
# for file in failed_files:
#     print(f" - {file}")

# %%
# # Folder tempat file CSV yang sudah diekstrak
# csv_folder = 'csv/'

# # File hasil penggabungan akhir
# combined_output_file = 'final_combined_output2.csv'

# # Daftar semua file CSV di dalam folder
# csv_files = [f for f in os.listdir(csv_folder) if f.endswith('.CSV') or f.endswith('.csv')][:5000]

# # Daftar file yang berhasil dan gagal dibaca
# successful_files = []
# failed_files = []

# # Buat header untuk file keluaran hanya sekali (di file pertama)
# header_written = False

# # Loop melalui semua file CSV
# for file in csv_files:
#     file_path = os.path.join(csv_folder, file)
    
#     try:
#         # Membaca file CSV dengan delimiter tab
#         df = pd.read_csv(file_path, sep='\t', engine='python')
        
#         # Simpan langsung ke file keluaran, tambahkan header hanya untuk file pertama
#         df.to_csv(combined_output_file, mode='a', header=not header_written, index=False)
#         header_written = True
        
#         successful_files.append(file)
#         print(f"Successfully read and added {file}")
#     except Exception as e:
#         # Jika gagal, tambahkan file ke daftar yang gagal
#         failed_files.append(file)
#         print(f"Failed to read {file}: {str(e)}")

# # Print hasil file yang sukses dan gagal
# print(f"\nSuccessfully processed {len(successful_files)} files:")
# for file in successful_files:
#     print(f" - {file}")

# print(f"\nFailed to process {len(failed_files)} files:")
# for file in failed_files:
#     print(f" - {file}")

# %%
import pandas as pd

# Link untuk file yang berisi header/nama kolom
link = "https://raw.githubusercontent.com/linwoodc3/gdelt2HeaderRows/master/schema_csvs/GDELT_2.0_Events_Column_Labels_Header_Row_Sep2016.csv"

# Membaca file header dari URL
header = pd.read_csv(link)

# Mengambil hanya kolom pertama yang berisi nama-nama kolom
column_names = header.iloc[:, 0].tolist()

# Baca file CSV utama dengan nama kolom dari file header
df = pd.read_csv("final_combined_output2.csv", names=column_names, header=None)
# Out:
# C:\Users\Samuel Chinson\AppData\Local\Temp\ipykernel_6576\1835600188.py:13: DtypeWarning: Columns (14,24,26,27,28,48,49,56,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("final_combined_output2.csv", names=column_names, header=None)

# %%
# import os
# import pandas as pd

# # Folder tempat semua file CSV berada
# csv_folder = 'csv/'  # Sesuaikan dengan folder tempat penyimpanan file CSV Anda

# # Nama file output untuk menyimpan data yang telah difilter
# filtered_output_file = 'filtered_large_data.csv'

# # Daftar semua file CSV di dalam folder
# csv_files = [os.path.join(csv_folder, f) for f in os.listdir(csv_folder) if f.endswith('.CSV') or f.endswith('.csv')]

# # Ukuran setiap chunk (jumlah baris yang dibaca sekaligus)
# chunksize = 500000  # Sesuaikan ukuran ini dengan kapasitas memori Anda

# # Link untuk file yang berisi header/nama kolom
# header_url = "https://raw.githubusercontent.com/linwoodc3/gdelt2HeaderRows/master/schema_csvs/GDELT_2.0_Events_Column_Labels_Header_Row_Sep2016.csv"
# header_df = pd.read_csv(header_url)

# # Mengambil hanya kolom pertama yang berisi nama-nama kolom
# column_names = header_df.iloc[:, 0].tolist()

# # Flag untuk menulis header hanya sekali pada file output
# header_written = False

# # Memproses setiap file CSV dalam folder
# for csv_file in csv_files:
#     print(f"Processing file: {csv_file}")
    
#     # Membaca file CSV besar secara bertahap menggunakan chunksize dan header yang diberikan
#     for chunk in pd.read_csv(csv_file, sep='\t', names=column_names, chunksize=chunksize, low_memory=False):
#         try:
#             # Filter data sesuai kondisi: kolom 'ActionGeo_CountryCode' = 'ID'
#             filtered_chunk = chunk[chunk['ActionGeo_CountryCode'] == 'ID']
            
#             # Hapus duplikat berdasarkan semua kolom
#             filtered_chunk = filtered_chunk.drop_duplicates()
            
#             # Simpan hasil filter langsung ke file output dengan mode append
#             if not filtered_chunk.empty:
#                 filtered_chunk.to_csv(filtered_output_file, mode='a', header=not header_written, index=False)
#                 header_written = True
#                 print(f"Appended {len(filtered_chunk)} rows to {filtered_output_file}")
                
#         except Exception as e:
#             print(f"Failed to process chunk in file {csv_file}: {str(e)}")

# print(f"Filtering complete. Filtered data saved to {filtered_output_file}")

# %%
df_country = pd.read_csv("filtered_large_data.csv")
df_country.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     1021420253  20220101     202201  2022     2022.0027        IDN
# 1     1021420254  20220101     202201  2022     2022.0027        IDN
# 2     1021420256  20220101     202201  2022     2022.0027        IDN
# 3     1021420260  20220101     202201  2022     2022.0027     IDNELI
# 4     1021421492  20220101     202201  2022     2022.0027        IDN
#
#    Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  ...  \
# 0   INDONESIA               IDN                  NaN              NaN  ...
# 1  INDONESIAN               IDN                  NaN              NaN  ...
# 2  INDONESIAN               IDN                  NaN              NaN  ...
# 3   INDONESIA               IDN                  NaN              NaN  ...
# 4  INDONESIAN               IDN                  NaN              NaN  ...
#
#   ActionGeo_Type                ActionGeo_FullName ActionGeo_CountryCode  \
# ...

# %%
print(df_country.columns)
# Out:
# Index(['GLOBALEVENTID', 'SQLDATE', 'MonthYear', 'Year', 'FractionDate',
#        'Actor1Code', 'Actor1Name', 'Actor1CountryCode', 'Actor1KnownGroupCode',
#        'Actor1EthnicCode', 'Actor1Religion1Code', 'Actor1Religion2Code',
#        'Actor1Type1Code', 'Actor1Type2Code', 'Actor1Type3Code', 'Actor2Code',
#        'Actor2Name', 'Actor2CountryCode', 'Actor2KnownGroupCode',
#        'Actor2EthnicCode', 'Actor2Religion1Code', 'Actor2Religion2Code',
#        'Actor2Type1Code', 'Actor2Type2Code', 'Actor2Type3Code', 'IsRootEvent',
#        'EventCode', 'EventBaseCode', 'EventRootCode', 'QuadClass',
#        'GoldsteinScale', 'NumMentions', 'NumSources', 'NumArticles', 'AvgTone',
#        'Actor1Geo_Type', 'Actor1Geo_FullName', 'Actor1Geo_CountryCode',
#        'Actor1Geo_ADM1Code', 'Actor1Geo_ADM2Code', 'Actor1Geo_Lat',
#        'Actor1Geo_Long', 'Actor1Geo_FeatureID', 'Actor2Geo_Type',
#        'Actor2Geo_FullName', 'Actor2Geo_CountryCode', 'Actor2Geo_ADM1Code',
# ...

# %%
event_code_counts = df_country['EventCode'].value_counts()
print(event_code_counts)
# Out:
# EventCode
# 42      50579
# 43      48033
# 40      45448
# 10      37768
# 51      31396
#         ...
# 1223        1
# 1623        1
# 313         1
# 351         1
# 1622        1
# Name: count, Length: 222, dtype: int64

# %%
cameo = pd.read_csv('cameo.csv')
cameo = cameo.drop(columns=['Unnamed: 0'])
cameo.head()
# Out:
#    event_code                                 name
# 0           1                MAKE PUBLIC STATEMENT
# 1          10  Make statement, not specified below
# 2          11                      Decline comment
# 3          12             Make pessimistic comment
# 4          13              Make optimistic comment

# %%
cameo.set_index('event_code', inplace=True)

# %%
df_merged = df_country.merge(cameo, left_on='EventCode', right_index=True, how='left')
df_merged
# Out:
#         GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0          1021420253  20220101     202201  2022     2022.0027        IDN
# 1          1021420254  20220101     202201  2022     2022.0027        IDN
# 2          1021420256  20220101     202201  2022     2022.0027        IDN
# 3          1021420260  20220101     202201  2022     2022.0027     IDNELI
# 4          1021421492  20220101     202201  2022     2022.0027        IDN
# ...               ...       ...        ...   ...           ...        ...
# 498164     1199394397  20240920     202409  2024     2024.7123        REB
# 498165     1199394467  20240920     202409  2024     2024.7123        SEP
# 498165     1199394467  20240920     202409  2024     2024.7123        SEP
# 498166     1199394469  20240920     202409  2024     2024.7123        SEP
# 498166     1199394469  20240920     202409  2024     2024.7123        SEP
#
#               Actor1Name Actor1CountryCode Actor1KnownGroupCode  \
# ...

# %%
print(df_merged.columns)
# Out:
# Index(['GLOBALEVENTID', 'SQLDATE', 'MonthYear', 'Year', 'FractionDate',
#        'Actor1Code', 'Actor1Name', 'Actor1CountryCode', 'Actor1KnownGroupCode',
#        'Actor1EthnicCode', 'Actor1Religion1Code', 'Actor1Religion2Code',
#        'Actor1Type1Code', 'Actor1Type2Code', 'Actor1Type3Code', 'Actor2Code',
#        'Actor2Name', 'Actor2CountryCode', 'Actor2KnownGroupCode',
#        'Actor2EthnicCode', 'Actor2Religion1Code', 'Actor2Religion2Code',
#        'Actor2Type1Code', 'Actor2Type2Code', 'Actor2Type3Code', 'IsRootEvent',
#        'EventCode', 'EventBaseCode', 'EventRootCode', 'QuadClass',
#        'GoldsteinScale', 'NumMentions', 'NumSources', 'NumArticles', 'AvgTone',
#        'Actor1Geo_Type', 'Actor1Geo_FullName', 'Actor1Geo_CountryCode',
#        'Actor1Geo_ADM1Code', 'Actor1Geo_ADM2Code', 'Actor1Geo_Lat',
#        'Actor1Geo_Long', 'Actor1Geo_FeatureID', 'Actor2Geo_Type',
#        'Actor2Geo_FullName', 'Actor2Geo_CountryCode', 'Actor2Geo_ADM1Code',
# ...

# %%
# Menghapus duplikat berdasarkan seluruh kolom
df_cleaned = df_merged.drop_duplicates()

# %% [markdown]
# ## **1. Analisis Distribusi Pemberitaan Kejadian/Event Terkait Indonesia**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import numpy as np
from shapely.geometry import Point

# %%
# Mengkonversi kolom SQLDATE menjadi datetime
df_cleaned['SQLDATE'] = pd.to_datetime(df_cleaned['SQLDATE'], format='%Y%m%d')

# Menghitung jumlah event per bulan
temporal_event_count = df_cleaned.resample('M', on='SQLDATE').size()

# Visualisasi distribusi event secara temporal dengan line chart
plt.figure(figsize=(10, 6))
temporal_event_count.plot(color='blue', linewidth=2)
plt.title('Distribusi Temporal Event di Indonesia', fontsize=15)
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Samuel Chinson\AppData\Local\Temp\ipykernel_6576\3111095265.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   temporal_event_count = df_cleaned.resample('M', on='SQLDATE').size()

# %% [markdown]
# **Analisis dari visualisasi diatas:**
# - Ada lonjakan yang sangat signifikan dalam jumlah event setelah tahun 2020. Lonjakan ini mungkin berkaitan dengan peristiwa besar seperti pandemi COVID-19, perubahan kebijakan publik yang signifikan, atau dinamika sosial-politik yang lebih intens di Indonesia pada tahun-tahun tersebut.
#
# - Perubahan drastis ini juga dapat dikaitkan dengan perubahan ekosistem media, seperti pertumbuhan media sosial, peningkatan jumlah media online, atau peningkatan pelaporan berita terkait Indonesia di skala global. Platform baru seperti media digital yang lebih intens dalam melaporkan berita mungkin menyebabkan lonjakan pelaporan event, khususnya di periode pasca-2020. Tren ini konsisten dengan peningkatan akses informasi dan laporan dari media yang lebih terhubung secara global.
#
# - Ada kemungkinan bahwa data GDELT sebelum 2020 tidak sepenuhnya lengkap, sehingga distribusi data yang lebih padat setelah 2020 mungkin lebih representatif dari keadaan sebenarnya. Mungkin terdapat pembaruan dalam cara data dikumpulkan atau diintegrasikan ke dalam sistem GDELT setelah tahun 2020. Perubahan dalam metodologi atau cakupan data bisa menjadi penyebab utama pola yang terlihat.

# %% [markdown]
# ## **2. Pilih salah satu event yang menarik**
# ## **3. Visualisasikan event secata spatial yang dipilih dalam bentuk proyeksi peta menggunakan Geo Pandas atau yang lain**

# %%
# Filter EventCode 111 untuk event di Indonesia
df_111 = df_cleaned[df_cleaned['EventCode'] == 111]

# Handle missing data (drop rows with missing coordinates)
df_111 = df_111.dropna(subset=['Actor1Geo_Long', 'Actor1Geo_Lat'])

# Buat GeoDataFrame dengan kolom longitude dan latitude
geometry = [Point(xy) for xy in zip(df_111['Actor1Geo_Long'], df_111['Actor1Geo_Lat'])]
gdf_111 = gpd.GeoDataFrame(df_111, geometry=geometry)

# Atur sistem koordinat CRS (Coordinate Reference System) ke WGS84
gdf_111.crs = "EPSG:4326"

# Pastikan untuk menyesuaikan path ke lokasi file yang sudah diekstrak
world = gpd.read_file("ne_110m_admin_0_countries.shp")

# Koordinat bounding box Indonesia
minx, miny, maxx, maxy = 95, -11, 141, 6  # Sekitar koordinat Indonesia

# Plotting peta
fig, ax = plt.subplots(figsize=(15, 10))

# Potong peta dunia hanya untuk wilayah Indonesia
world_indonesia = world.cx[minx:maxx, miny:maxy]

# Plot data peta dunia di sekitar Indonesia
world_indonesia.plot(ax=ax, color='lightgrey', edgecolor='black')

# Buat kolom baru untuk ukuran marker
gdf_111['size'] = np.log(gdf_111.shape[0]) * 5  # Menyesuaikan ukuran marker

# Plot event dengan EventCode 111
sc = gdf_111.plot(ax=ax, color='red', markersize=gdf_111['size'], alpha=0.7, marker='o', label='EventCode 111')

# Plot beberapa kota besar di Indonesia (menambahkan informasi geografis)
cities = {
    "Jakarta": (106.8456, -6.2088),
    "Surabaya": (112.7508, -7.2575),
    "Medan": (98.6722, 3.5897),
    "Denpasar": (115.2167, -8.6500),
}

for city, coord in cities.items():
    plt.text(coord[0], coord[1], city, fontsize=9, ha='right', color='blue', fontweight='bold')

# Fokus pada wilayah Indonesia dengan bounding box
ax.set_xlim(minx, maxx)
ax.set_ylim(miny, maxy)

# Tambahkan title dan label
plt.title('Visualisasi Geospasial Event dengan EventCode 111', fontsize=18, fontweight='bold')
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)

# Tambahkan legenda
plt.legend(loc='upper left')

# Tambahkan grid
ax.grid(color='grey', linestyle='--', linewidth=0.5)

# Tampilkan peta
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **4. Visualisasi jumlah event secara temporal menggunakan visualisasi yang cocok**

# %%
# Mengubah kolom 'SQLDATE' menjadi tipe datetime
df_111['Date'] = pd.to_datetime(df_111['SQLDATE'], format='%Y%m%d')

# Agregasi jumlah event per bulan
event_counts_monthly = df_111.groupby(df_111['Date'].dt.to_period('M')).size()

# Visualisasi jumlah event per bulan
plt.figure(figsize=(12, 6))
event_counts_monthly.plot(kind='line', marker='o', color='cornflowerblue', linewidth=2)
plt.title('Jumlah Event per Bulan (EventCode 111)', fontsize=15)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Jumlah Event', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## **5. Visualisasikan Rata-Rata Tone Event yang diplih (AvgTone) secara temporal menggunakan visualisasi yang cocok**

# %%
# Ubah kolom 'SQLDATE' menjadi tipe datetime
df_cleaned['Date'] = pd.to_datetime(df_cleaned['SQLDATE'], format='%Y%m%d')

# Agregasi rata-rata tone event per hari
avg_tone_per_day = df_cleaned.groupby(df_cleaned['Date'].dt.date)['AvgTone'].mean()

# Membuat DataFrame dari hasil agregasi
avg_tone_df = pd.DataFrame(avg_tone_per_day).reset_index()
avg_tone_df.columns = ['Date', 'Avg_Tone']

# Plotting rata-rata tone secara temporal
plt.figure(figsize=(12, 6))
plt.plot(avg_tone_df['Date'], avg_tone_df['Avg_Tone'], marker='o', linestyle='-', color='orange')
plt.title('Rata-Rata Tone Event Secara Temporal', fontsize=18, fontweight='bold')
plt.xlabel('Tanggal', fontsize=12)
plt.ylabel('Rata-Rata Tone', fontsize=12)
plt.xticks(rotation=45)
plt.grid(color='grey', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **6. Cari siapa 10 aktor teribat yang paling dominan dalam event yang dipilih**

# %%
# Hitung jumlah kemunculan setiap aktor
top_actors = df_111['Actor1Name'].value_counts().head(10)

# Reverse the order for the bar chart to show the least dominant to the most dominant actors
top_actors_reversed = top_actors[::-1]

# Visualisasi dengan urutan dibalik
plt.figure(figsize=(12, 6))
top_actors_reversed.plot(kind='barh', color='skyblue')
plt.title('10 Aktor Terlibat Paling Dominan dalam Event dengan EventCode 111', fontsize=15)
plt.xlabel('Jumlah Kemunculan', fontsize=12)
plt.ylabel('Aktor', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## **7. Cari 3 (tiga) insight yang lain**

# %% [markdown]
# **1. Distribusi Event Berdasarkan Hari dalam Seminggu**

# %%
# Menambahkan kolom hari dalam seminggu
df_cleaned['DayOfWeek'] = df_cleaned['Date'].dt.day_name()

# Filter EventCode 111
df_111 = df_cleaned[df_cleaned['EventCode'] == 111]

# Urutan hari dalam seminggu
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Konversi kolom DayOfWeek menjadi kategori dengan urutan
df_111['DayOfWeek'] = pd.Categorical(df_111['DayOfWeek'], categories=days_order, ordered=True)

# Hitung jumlah event per hari dalam seminggu
event_day_counts = df_111['DayOfWeek'].value_counts().sort_index()

# Visualisasi bar chart
plt.figure(figsize=(10, 6))
event_day_counts.plot(kind='bar', color='skyblue')
plt.title('Distribusi EventCode 111 Berdasarkan Hari dalam Seminggu', fontsize=15)
plt.xlabel('Hari dalam Seminggu')
plt.ylabel('Jumlah Event')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Samuel Chinson\AppData\Local\Temp\ipykernel_6576\3553905955.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_111['DayOfWeek'] = pd.Categorical(df_111['DayOfWeek'], categories=days_order, ordered=True)

# %% [markdown]
# **Analisis**
#
# - INDONESIA dan INDONESIAN sebagai aktor paling dominan mengindikasikan bahwa banyak kritik dan kecaman dalam negeri ditujukan pada pemerintah, kebijakan, atau pihak-pihak tertentu di dalam negeri. Keterlibatan entitas seperti JAKARTA, PRESIDENT, dan GOVERNMENT menandakan bahwa sebagian besar kritik kemungkinan berpusat pada isu politik atau administrasi yang terjadi selama hari kerja (Senin hingga Jumat), ketika aktivitas pemerintahan paling intens.
#
# - Dari segi distribusi, kita bisa memprediksi bahwa penurunan frekuensi event pada akhir pekan menunjukkan bahwa aktivitas kritik atau kecaman berkurang selama hari Sabtu dan Minggu. Hal ini mungkin karena aktivitas pemerintahan, korporasi, dan media juga melambat pada akhir pekan, sehingga tidak banyak keputusan atau tindakan kontroversial yang terjadi pada waktu tersebut. MEDIA mungkin ikut memainkan peran penting di sini, dengan kritik melalui media massa lebih intens selama hari kerja, mengikuti siklus berita harian yang lebih aktif pada masa tersebut.
#
# - COMPANY dan GOVERNMENT juga menjadi target kritik. Banyak perusahaan besar yang mungkin menghadapi kritik terkait kebijakan atau tindakan yang mempengaruhi masyarakat luas, terutama terkait ekonomi atau lingkungan. Kritik ini kemungkinan besar muncul lebih sering pada hari kerja saat berita tentang kegiatan perusahaan dipublikasikan.
#
# - CHINA dan MALAYSIA sebagai aktor internasional menunjukkan bahwa kritik tidak hanya ditujukan pada aktor dalam negeri, tetapi juga terhadap negara lain, mungkin terkait dengan isu diplomasi, perdagangan, atau kebijakan luar negeri yang melibatkan Indonesia. Event terkait ini mungkin juga mengikuti pola distribusi serupa, dengan puncak di hari kerja.

# %% [markdown]
# **2. Visualisasi Korelasi Antara Rata-Rata Tone dan Jumlah Event**

# %%
# Hitung jumlah event per bulan
monthly_event_counts = df_111.resample('M', on='Date').size()

# Hitung rata-rata tone per bulan
monthly_avg_tone = df_111.resample('M', on='Date')['AvgTone'].mean()

# Gabungkan jumlah event dan rata-rata tone
event_tone_df = pd.DataFrame({'EventCount': monthly_event_counts, 'AvgTone': monthly_avg_tone})

# Visualisasi
plt.figure(figsize=(12, 6))
plt.plot(event_tone_df.index, event_tone_df['EventCount'], marker='o', color='blue', label='Jumlah Event')
plt.plot(event_tone_df.index, event_tone_df['AvgTone'], marker='o', color='orange', label='Rata-Rata Tone')
plt.title('Korelasi antara Jumlah Event dan Rata-Rata Tone per Bulan', fontsize=15)
plt.xlabel('Tanggal', fontsize=12)
plt.ylabel('Jumlah Event / Rata-Rata Tone', fontsize=12)
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Samuel Chinson\AppData\Local\Temp\ipykernel_6576\972791574.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_event_counts = df_111.resample('M', on='Date').size()
# C:\Users\Samuel Chinson\AppData\Local\Temp\ipykernel_6576\972791574.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg_tone = df_111.resample('M', on='Date')['AvgTone'].mean()

# %% [markdown]
# **Analisis**
#
# - Selama beberapa tahun pertama, baik jumlah event maupun rata-rata tone cenderung sangat rendah dan stabil. Ini bisa mengindikasikan periode yang relatif tenang atau tanpa banyak peristiwa yang signifikan.
#
# - Terjadi lonjakan drastis pada sekitar tahun 2022, baik dalam jumlah event maupun rata-rata tone. Ini menandakan adanya periode yang sangat aktif dengan banyak peristiwa yang terjadi, dan peristiwa-peristiwa ini cenderung memiliki tone yang lebih tinggi (baik positif atau negatif).
#
# - Setelah lonjakan tersebut, kedua metrik menunjukkan fluktuasi yang cukup tinggi. Ini mengindikasikan adanya dinamika yang cepat dalam situasi, dengan periode-periode di mana banyak peristiwa terjadi bergantian dengan periode yang lebih tenang.

# %% [markdown]
# **3. Keterlibatan Media dalam Peliputan Event**

# %%
# Agregasi jumlah artikel per tanggal
df_111['Date'] = pd.to_datetime(df_111['SQLDATE'], format='%Y%m%d')
event_article_counts = df_111.groupby(df_111['Date'].dt.date)['NumArticles'].sum()

# Visualisasi line plot
plt.figure(figsize=(10, 6))
event_article_counts.plot(kind='line', color='green')
plt.title('Keterlibatan Media dalam Peliputan EventCode 111', fontsize=15)
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Artikel')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Samuel Chinson\AppData\Local\Temp\ipykernel_6576\4243817648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_111['Date'] = pd.to_datetime(df_111['SQLDATE'], format='%Y%m%d')

# %% [markdown]
# **Analisis**
#
# - Pada awal periode yang ditampilkan, jumlah artikel yang meliput EventCode 111 relatif rendah dan stabil. Ini mengindikasikan bahwa peristiwa ini mungkin tidak terlalu menarik perhatian media pada awalnya.
#
# - Terdapat beberapa lonjakan tajam dalam jumlah artikel, terutama di sekitar tahun 2022. Lonjakan ini menunjukkan adanya peningkatan minat media yang signifikan terhadap EventCode 111 pada periode tersebut.
#
# - Setelah lonjakan, jumlah artikel cenderung fluktuatif, dengan beberapa puncak dan lembah yang signifikan. Ini mengindikasikan bahwa minat media terhadap peristiwa ini terus berfluktuasi seiring berjalannya waktu.
#
# Jika kita berasumsi bahwa peningkatan jumlah artikel terkait dengan EventCode 111 mengindikasikan adanya peningkatan diskusi publik, termasuk kritik dan kecaman, maka dapat ditarik beberapa kesimpulan:
#
# 1. Lonjakan jumlah artikel mengindikasikan bahwa EventCode 111 telah menjadi topik diskusi yang lebih luas di kalangan publik.
#
# 2. Fluktuasi yang tinggi dalam jumlah artikel mungkin mencerminkan sifat kontroversial dari EventCode 111, yang memicu berbagai reaksi dan opini yang berbeda-beda.
#
# 3. Lonjakan-lonjakan tertentu mungkin disebabkan oleh agenda media yang ingin menyorot peristiwa ini pada waktu-waktu tertentu, misalnya untuk meningkatkan rating atau penjualan.
